# %%
import pandas as pd

# %%
df = pd.read_csv("data/salary - salary.csv")

# %%
df
# Out:
#        Хүйс        Аймаг  Код  1995  1996  1997  1998  1999  2000  2001  ...  \
# 0      Бүгд    Улсын дүн    0  24.4  31.9  37.8  48.1  55.4  62.3  65.2  ...
# 1      Бүгд   Баруун бүс    1   NaN   NaN   NaN   NaN   NaN  58.2  54.0  ...
# 2      Бүгд   Баян-Өлгий  183   NaN   NaN   NaN   NaN   NaN  48.9  52.2  ...
# 3      Бүгд   Говь-Алтай  182   NaN   NaN   NaN   NaN   NaN  64.3  50.4  ...
# 4      Бүгд       Завхан  181   NaN   NaN   NaN   NaN   NaN  50.7  52.9  ...
# ..      ...          ...  ...   ...   ...   ...   ...   ...   ...   ...  ...
# 79  Эрэгтэй       Дорнод  421   NaN   NaN   NaN   NaN   NaN  45.9  54.1  ...
# 80  Эрэгтэй    Сүхбаатар  422   NaN   NaN   NaN   NaN   NaN  62.0  63.2  ...
# 81  Эрэгтэй       Хэнтий  423   NaN   NaN   NaN   NaN   NaN  42.3  53.9  ...
# 82  Эрэгтэй  Улаанбаатар    5   NaN   NaN   NaN   NaN   NaN  73.6  83.0  ...
# 83  Эрэгтэй  Улаанбаатар  511   NaN   NaN   NaN   NaN   NaN  73.6  83.0  ...
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        Хүйс        Аймаг  Код  1995  1996  1997  1998  1999  2000  2001  ...  \
# 0      Бүгд    Улсын дүн    0  24.4  31.9  37.8  48.1  55.4  62.3  65.2  ...
# 1      Бүгд   Баруун бүс    1   NaN   NaN   NaN   NaN   NaN  58.2  54.0  ...
# 2      Бүгд   Баян-Өлгий  183   NaN   NaN   NaN   NaN   NaN  48.9  52.2  ...
# 3      Бүгд   Говь-Алтай  182   NaN   NaN   NaN   NaN   NaN  64.3  50.4  ...
# 4      Бүгд       Завхан  181   NaN   NaN   NaN   NaN   NaN  50.7  52.9  ...
# ..      ...          ...  ...   ...   ...   ...   ...   ...   ...   ...  ...
# 79  Эрэгтэй       Дорнод  421   NaN   NaN   NaN   NaN   NaN  45.9  54.1  ...
# 80  Эрэгтэй    Сүхбаатар  422   NaN   NaN   NaN   NaN   NaN  62.0  63.2  ...
# 81  Эрэгтэй       Хэнтий  423   NaN   NaN   NaN   NaN   NaN  42.3  53.9  ...
# 82  Эрэгтэй  Улаанбаатар    5   NaN   NaN   NaN   NaN   NaN  73.6  83.0  ...
# 83  Эрэгтэй  Улаанбаатар  511   NaN   NaN   NaN   NaN   NaN  73.6  83.0  ...
#
# ...

# %%
df.columns
# Out:
# Index(['Хүйс', 'Аймаг', 'Код', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021', '2022', '2023', '2024'],
#       dtype='object')
