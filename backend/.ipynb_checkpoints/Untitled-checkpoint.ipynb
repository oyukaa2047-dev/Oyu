# %%
import pandas as pd

# %%
df= pd.read_excel("data/turshilt ai.xlsx")

# %%
df
# Out:
#                Дамжлага    № Будааны ороомог Бүлгуги  Түүхий эдийн код  \
# 0    Будаа боловсруулах    1               1700001037       2500000034
# 1                   NaN    2               1700001037                1
# 2                   NaN    3               1700001037       2500000054
# 3                   NaN    4               1700001037       2500000003
# 4                   NaN    5               1700001037       2500000055
# ..                  ...  ...                      ...              ...
# 103            Савлагаа    1               1700001008       1200002086
# 104                 NaN    2               1700001008       1200000998
# 105                 NaN    3               1700001008       1200002087
# 106                 NaN    4               1700001008       1200002094
# 107               Нийт   NaN                      NaN              NaN
#
#                          Түүхий эдийн нэр  Unnamed: 5 Х/Н       1 порц  \
# ...

# %%
sheets = pd.ExcelFile("data/turshilt ai.xlsx").sheet_names

# %%
sheets
# Out:
# ['Тех карт', 'Хасалт', 'Хассан ', 'Үйлдвэрлэл', 'үлдэгдэл ']

# %%
### миний хийхийг хүссэн зүйл 
# тех картын дагуу зөрүү үүссэн эсэх 
## тухайн зөрүү үүссэн бараа ямар хоолонд орж байгааг 
### хасалт хэmрэлт үүссэн бараа
### хасалт хэмнэлт үүссэн бараа
#### Үйлдвэрлэлийн өртөг тех картаас гарч байгаа хасалтын өртөгтэй хэр зэрэг зөрүүтэй байна 
### өртөг үнэ өөрчлөгдсөн эсэх /өмнөх сарын дата орох шаардлагатай дараагийн дата
